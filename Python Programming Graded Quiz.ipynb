# %%
import pandas as pd
food_dataset = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin1')

# %%
food_dataset.head(50)
# Out:
#     Area Code     Area  Item Code                      Item  Element Code  \
# 0           4  Algeria       2501                Population           511
# 1           4  Algeria       2501                Population          5301
# 2           4  Algeria       2901               Grand Total           664
# 3           4  Algeria       2901               Grand Total           674
# 4           4  Algeria       2901               Grand Total           684
# 5           4  Algeria       2903          Vegetal Products           664
# 6           4  Algeria       2903          Vegetal Products           674
# 7           4  Algeria       2903          Vegetal Products           684
# 8           4  Algeria       2941           Animal Products           664
# 9           4  Algeria       2941           Animal Products           674
# 10          4  Algeria       2941           Animal Products           684
# 11          4  Algeria       2905  Cereals - Excluding Beer          5511
# ...

# %%
food_dataset[['Y2017','Area']].sort_values(by = 'Y2017',ascending = False)
# Out:
#           Y2017      Area
# 42973  190873.0   Nigeria
# 43129  117702.0   Nigeria
# 43133  112625.0   Nigeria
# 19008  106400.0  Ethiopia
# 16236   96443.0     Egypt
# ...         ...       ...
# 60208       NaN  Zimbabwe
# 60256       NaN  Zimbabwe
# 60355       NaN  Zimbabwe
# 60357       NaN  Zimbabwe
# 60646       NaN  Zimbabwe
#
# [60943 rows x 2 columns]

# %%
qll.sort_values(ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 qll.sort_values(ascending = False)
#
# NameError: name 'qll' is not defined

# %%
food_dataset['Y2017'].std()
# Out:
# 1671.8623590572788

# %%
food_dataset['Y2017'].mean()
# Out:
# 140.917764860268

# %%
array =([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

# %%
S = [['him', 'sell'], [90, 28, 43]]

# %%
S[0][1][1]
# Out:
# 'e'

# %%
fd = food_dataset[['Y2017','Area']].sort_values(by = 'Area',ascending = True)

# %%
fd.head(10)
# Out:
#        Y2017     Area
# 0    41389.0  Algeria
# 879     21.0  Algeria
# 878      0.0  Algeria
# 877      1.0  Algeria
# 876     22.0  Algeria
# 875      0.0  Algeria
# 874      0.0  Algeria
# 873      7.0  Algeria
# 880      0.5  Algeria
# 872     15.0  Algeria

# %%
food_dataset.loc[(food_dataset['Area'] == 'Madagascar') & (food_dataset['Element'] == 'Protein supply quantity (g/capita/day)')].sum()
# Out:
# Area Code                                                   14319
# Area            MadagascarMadagascarMadagascarMadagascarMadaga...
# Item Code                                                  299405
# Item            Grand TotalVegetal ProductsAnimal ProductsCere...
# Element Code                                                74814
# Element         Protein supply quantity (g/capita/day)Protein ...
# Unit            g/capita/dayg/capita/dayg/capita/dayg/capita/d...
# Y2014                                                      177.79
# Y2015                                                      173.05
# Y2016                                                       173.4
# Y2017                                                      175.75
# Y2018                                                      176.64
# dtype: object

# %%
food_dataset[(food_dataset['Element'] == 'Processing') & (food_dataset['Y2017'] )].sum()
# Out:
# Area Code                                                   89222
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                                 1694725
# Item            Cereals - Excluding BeerBarley and productsSug...
# Element Code                                              3227399
# Element         ProcessingProcessingProcessingProcessingProces...
# Unit            1000 tonnes1000 tonnes1000 tonnes1000 tonnes10...
# Y2014                                                    281972.0
# Y2015                                                    287014.0
# Y2016                                                    280605.0
# Y2017                                                    292836.0
# Y2018                                                    308410.0
# dtype: object

# %%
food_dataset[(food_dataset['Item'] == 'Wine') ].sum()
# Out:
# Area Code                                                   66206
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                                 1319535
# Item            WineWineWineWineWineWineWineWineWineWineWineWi...
# Element Code                                              1818328
# Element         ProductionImport QuantityStock VariationExport...
# Unit            1000 tonnes1000 tonnes1000 tonnes1000 tonnes10...
# Y2014                                                     4497.36
# Y2015                                                     4251.81
# Y2016                                                     3872.09
# Y2017                                                     4178.02
# Y2018                                                     4039.32
# dtype: object

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]
col = ['Age','Nationality','Overall']

# %%
x = food_dataset[['Area','Y2017']].sort_values(by = 'Area' )

# %%
food_dataset['Area'].nunique()
# Out:
# 49

# %%
food_dataset['Item'].unique()
# Out:
# array(['Population', 'Grand Total', 'Vegetal Products', 'Animal Products',
#        'Cereals - Excluding Beer', 'Wheat and products',
#        'Rice and products', 'Barley and products', 'Maize and products',
#        'Rye and products', 'Oats', 'Millet and products',
#        'Sorghum and products', 'Cereals, Other', 'Starchy Roots',
#        'Cassava and products', 'Potatoes and products', 'Sweet potatoes',
#        'Yams', 'Roots, Other', 'Sugar Crops', 'Sugar cane', 'Sugar beet',
#        'Sugar & Sweeteners', 'Sugar (Raw Equivalent)',
#        'Sweeteners, Other', 'Honey', 'Pulses', 'Beans', 'Peas',
#        'Pulses, Other and products', 'Treenuts', 'Nuts and products',
#        'Oilcrops', 'Soyabeans', 'Groundnuts (Shelled Eq)',
#        'Sunflower seed', 'Rape and Mustardseed', 'Cottonseed',
#        'Coconuts - Incl Copra', 'Sesame seed',
#        'Olives (including preserved)', 'Oilcrops, Other',
#        'Vegetable Oils', 'Soyabean Oil', 'Groundnut Oil',
# ...
